# %% [markdown]
# # RL Experiment 06: Adaptive Probabilities
#
# Shows how to toggle adaptive GA probabilities via config overrides.

# %%
from schedule_engine.notebooks import build_notebook_config

config = build_notebook_config(overrides={"use_adaptive_probabilities": True})
print(f"Adaptive probabilities enabled: {config.ga.use_adaptive_probabilities}")
